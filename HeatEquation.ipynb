# %% [markdown]
# # Project Heat Equation

# %% [markdown]
# Please fill in the names of the team mebers.
#
# <div class="alert alert-block alert-danger">
#
# <b>Team: XX</b>
# - Max Mustermann 471108
# - XX
# - XX
#
# <b>Result:</b>
#
# | Task   |  1  |  2  |  3  |  4  |  5  |  6  | Sum   |
# |--------|-----|-----|-----|-----|-----|-----|-------|
# | Points | ?/2 | ?/5 | ?/5 | ?/5 | ?/1 | ?/2 | ??/20 |
#
# </div>

# %% [markdown]
# ## Packages
#
# <div class="alert alert-block alert-danger">
#
# <b>Important: Do not import other packages or libraries!</b>
#
# </div>

# %% [markdown]
# ### Python

# %%
from platform import python_version
print('python version = '+ python_version())

# %% [markdown]
# ### Display images and videos

# %%
from IPython.display import HTML, Image, IFrame, YouTubeVideo

# %% [markdown]
# ### NumPy

# %%
import numpy as np
print('numpy version = '+ np.__version__)

# %% [markdown]
# ### Matplotlib

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
print('matplotlib version = '+ matplotlib.__version__)

# %% [markdown]
# ### Google Colab
# If you are using Google Colab mount drive and change directory.

# %%
if 'google.colab' in str(get_ipython()):
    print('Running on Google Colab')
    from google.colab import drive
    drive.mount('/content/gdrive')
    # %cd '/content/gdrive/MyDrive/Colab Notebooks/Modelling and Simulation/HeatEquation'
else:
    print('Not running on Google Colab')

# %% [markdown]
# ## 1 Modelling

# %% [markdown]
# Thermal conduction is something we all have experienced in many ways. Whether it be good thermal conduction like a cooking pan on a stove, or bad thermal conduction when wearing a jacket. Like mentioned the way a material is used can depend on the termal conduction of said material. Especially in the ever growing of CPUs and GPUs efficient thermal conduction plays an important role, to ensure performance and longevity of CPUs and GPUs.

# %%
YouTubeVideo('9joLYfayee8')

# %% [markdown]
# ## 2 Derivation of the heat equation

# %% [markdown]
# The law of conservation of energy is the basis of the heat equation, which states that energy is not lost or created, but merely transformed from one form to another. Mathematically it looks like this:

# %% [markdown]
# The heat equation comes directly from the *law of conservation of energy*:
# energy cannot be created or destroyed, only moved from one place to another.
#
# Consider a small piece of a rod in the interval $x, x+\Delta x$.
# The amount of thermal energy stored in this piece is proportional to the temperature: <br>
#
#
# Consider a small piece of a rod in the interval $[x, x+\Delta x]$.
# The amount of thermal energy stored in this piece is proportional to the temperature:
# $
# E = \rho c\, u(x,t)\, \Delta x .
# $
#
# Here,
# - $\rho$ denotes the density,
# - $c$ the specific heat capacity,
# - $u(x,t)$ the temperature.
#
#
# According to the conservation of energy, the rate of change of this energy equals the net heat flow into the interval.
#
# Using Fourier’s law, the heat flow is
# $$
# I = -k\,u_x,
# $$
# where $k$ is the thermal conductivity.
#
# The net inflow of heat is
# $$
# I(x) - I(x+\Delta x) \approx -I_x(x)\,\Delta x.
# $$
#
# Energy balance gives
# $$
# \rho c\, u_t \,\Delta x = -I_x\, \Delta x.
# $$
#
# Canceling $\Delta x$ yields
# $$
# \rho c\, u_t = -I_x.
# $$
#
# Using Fourier’s law again,
# $$
# I_x = -(k\,u_x)_x,
# $$
# we obtain
# $$
# u_t = \frac{k}{\rho c}\, u_{xx}.
# $$
#
# The constant
# $$
# a^2 = \frac{k}{\rho c}
# $$
# is called the *thermal diffusivity*, and the equation becomes
# $$
# u_t(x,t) = a^2 u_{xx}(x,t)
# $$

# %% [markdown]
# ## 3 Analytical treatment

# %% [markdown]
# ##  General overview about the heat equation
#
# The phenomenon of heat conduction describes the flow of heat within a body as the transport of thermal energy from warmer to colder regions. This heat transfer continues until the temperature becomes spatially uniform. It explains how thermal energy spreads without macroscopic motion of the material, as would occur in convection. The transport of thermal energy takes place through microscopic processes, such as collisions or vibrations within the material structure.
#
# The general heat conduction equation describes the temporal change of temperature as a result of heat flow within the body.
#
# In general, there are three common boundary conditions for the heat equation:
# Dirichlet boundary condition: the temperature is prescribed on the boundary.
# Neumann boundary condition: the normal heat flux through the boundary is prescribed.
# The Robin boundary condition: the heat flux at the boundary is proportional to the temperature difference between the boundary temperature and the ambient temperature, where the heat transfer coefficient determines the strength of heat exchange across the boundary.

# %% [markdown]
# ### 3.1 Thermal diffusity

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ### Task 1:  <font color=red>(1 points)</font>
#
# Calculation of a², the thermal diffusity. The thermal diffusity is a factor that entirely depends on the material.
#
# $a² = \frac{k}{\rho \cdot c}$
#
# <br>
#
# k is thermal conductivity, it measures how well a material conducts heat. A greater value suggests an easy heat flow, like in metals. A smaller value the opposite, like it can be found in wood.
#
# <br>
#
# $\rho$ is the density of the material, so the mass per unit volume.
#
# <br>
#
# $c$ is the specific heat capacity at constant pressure, meaning how much energy you need to raise 1 kg of material by 1 K. High $c$ means the material stores a lot of heat.
#
# <br>
#
# Below you can find links to help you **calculate the thermal diffusity a² for copper**:
#
# <br>
#
# Thermal conductivity k: $401 \frac{W}{m \cdot K}$ at 25°C $\qquad$ (You can see the values of other materials here: https://en.wikipedia.org/wiki/List_of_thermal_conductivities)
#
# Density $\rho$: $8.94 \frac{g}{cm³}$ at 25°C $\qquad$ (You can see the values of other materials here:https://en.wikipedia.org/wiki/Density)
#
# Specific heat capacity $c$ (Isobaric mass heat capacity): https://en.wikipedia.org/wiki/Table_of_specific_heat_capacities
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Solution of Task 1</b>
#
#
#
# </div>

# %% [markdown]
# Solution for Thermal Diffusivity of Copper
#
# Parameters:
# \begin{align*}
#     k &= 401 \, \text{W/(m$\cdot$K)} = 401 \, \text{J/(m$\cdot$K$\cdot$s)} \\
#     \rho &= 8.940 \, \text{g/cm$^3$} = 8940 \, \text{kg/m$^3$} \\
#     c &= 385 \, \text{J/(kg$\cdot$K)}
# \end{align*}
#
# Calculation of Thermal Diffusivity $a^2$
# The thermal diffusivity $a^2$ for copper is calculated as follows:
#
# \begin{align*}
#     a^2 &= \frac{k}{\rho \cdot c} \\
#         &= \frac{401}{8940 \times 385} \\
#         &\approx 1.165 \times 10^{-4} \, \text{m$^2$/s}
# \end{align*}
#
# Converting to $mm^2/s$
# \begin{align*}
#     a^2 &\approx 1.165 \times 10^{-4} \, \text{m$^2$/s} \times 10^6 \, \text{mm$^2$/m$^2$} \\
#         &\approx 116.5 \, \text{mm$^2$/s}
# \end{align*}

# %% [markdown]
# ### 3.2 Partial Differential Equations

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ### Task 2:  <font color=red>(3 points)</font>
#
# For this lab, the following modeling assumptions are made: A one-dimensional rod element is considered, whose heat flow occurs exclusively along the x-axis. The material of the rod is assumed to be homogeneous and isotropic. There are neither external nor internal heat sources. Dirichlet boundary conditions are applied with a uniform constant temperature of $0°C$. In this case, the equation describes a one-dimensional rod element cooling down in an ideal laboratory environment.
#
# This example is not realistic, but it was chosen to provide a smooth introduction to the topic.
#
#
# The boundary conditions are: $u(0,t) = 0 \quad \text{and} \quad u(\pi,t) = 0 , \qquad t \geq 0$
#
# The initial condition is: $u(x,0) = \qquad \begin{cases} 1, 0 < x < \pi, \\ 0, x=0, \text{ oder } x=\pi. \end{cases}$
#
# The heat equation is: $u_t(x,t) = a^2 \cdot u_{xx}(x,t)$
#
#
# In this task, please use the product ansatz $u(x,t)=X(x) \cdot T(t)$ to derive the general solution in the box below!
# If you have difficulties, this <a href="https://youtu.be/JC6tPsC3zts?t=58&si=Vmr_D8irxbTIJisd" rel="noopener noreferrer"> video </a> shows how to derive the general solution using the product ansatz.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Solution of Task 2</b>
#
#
#
# </div>

# %% [markdown]
# First, apply the product ansatz and derive with respect to time $t$.<br>
# $u(x,t) = X(x) \cdot T(t) \Rightarrow  u_t(x,t) = X(x) \cdot T_t(t)$
#
# Second, apply the product ansatz and take the second derivative with respect to the spatial variable $x$.<br>
# $u(x,t) = X(x) \cdot T(t) \Rightarrow u_{xx}(x,t) = X_{xx}(x) \cdot T(t)$
#
# Third, substitute the derivatives into the heat equation.<br>
# $X(x) \cdot T_t(t) = a^2 \cdot X_{xx}(x) \cdot T(t)$
#
# Fourth, separate the equation by time and spatial, by dividing both sides with the term $X(x) \cdot T(t) \cdot a^2$. <br> xxx
# $\frac{ X_{xx}(x)}{ X(x)}  =  \frac{T_t(t)}{a^2 \cdot T(t) }$
#
# Fifth, set both sides equal to the separation constant $w$.<br>
# $\frac{ X_{xx}(x)}{ X(x)}  =  \frac{T_t(t)}{a^2 \cdot T(t) } = w \qquad   w = const.$
#
# Sixth, solve the resulting ordinary differential equations separately, starting with the spatial equation.<br>
# $\frac{X_{xx}(x)}{X(x)} = w \Rightarrow 0 = -X_{xx}(x) + w \cdot  X(x)$
#
# Seventh, use the exponential ansatz to obtain the characteristic equation.<br>
# $0 = -\lambda^2\cdot e^{\lambda x} + w\cdot e^{\lambda x} \Rightarrow 0 = -\lambda^2 + w \Rightarrow \lambda_{1,2} = \pm \sqrt{w}$
#
# Eighth, insert these eigenvalues into the corresponding eigenfunction.<br>
# $X(x) = C_1 \cdot e^{x\cdot\sqrt{w}} + C_2 \cdot e^{-x \cdot \sqrt{w}}$
#
# Ninth, solve the ordinary differential equation for the time-dependent part.<br>
# $\frac{T_t(t)}{ a^2 \cdot T(t)} = w \Rightarrow T_t(t) = a^2 \cdot T(t) \cdot w$
#
# Tenth, use an exponential ansatz to obtain the characteristic equation.<br>
# $0 = -T_t(t) + a^2 \cdot T(t)\cdot w \Rightarrow 0 = -\lambda + a^2 \cdot w \Rightarrow \lambda = a^2 \cdot w$
#
# Eleventh, insert this eigenvalue into the corresponding eigenfunction.<br>
# $T(t) = C_3 \cdot e^{t \cdot a^2 \cdot w}$
#
# Twelfth, combine the spatial and temporal eigenfunctions to obtain the separated solution $u(x,t)=X(x) \cdot T(t)$.<br>
# $u(x,t)=(C_1 \cdot e^{x \cdot\sqrt{w}} + C_2\cdot e^{-x\cdot \sqrt{w}})\cdot C_3 \cdot e^{t \cdot a^2 \cdot w}$

# %% [markdown]
# ### 3.2.1 Boundary Conditions

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ### Task 3:  <font color=red>(2 points)</font>
#
# In the following task, apply the boundary conditions $u(0,t)=0$ and $u(\pi,t)=0$ to the solution you derived.
#
# If you need help, this <a href="https://youtu.be/JC6tPsC3zts?t=171&si=ctGNfgjI-G4cNzol" rel="noopener noreferrer"> video </a> shows how to apply boundary conditions to the heat equation.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Solution of Task 3</b>
#
#
#
# </div>

# %% [markdown]
# First, apply the boundary condition $u(0,t) = 0$ to the spatial part of the solution from task 2. <br>
# $X(0) = C_1 \cdot e^{0\sqrt{w}} + C_2 \cdot e^{-0\cdot \sqrt{w}}$
#
# Second, simplify the expression.<br>
# $X(0) = C_1 \cdot e^{0\sqrt{w}} + C_2 \cdot e^{-0\cdot \sqrt{w}} \Rightarrow X(0) = C_1 \cdot 1 + C_2 \cdot 1 \Rightarrow C_1 + C_2 = 0 \Rightarrow C_1 = -C_2 \Rightarrow |C_1| = |C_2| = C$
#
# Third, write the simplified spatial solution.<br>
# $X(x) = C_1 \cdot e^{x \cdot \sqrt{w}} - C_2 \cdot e^{-x \cdot \sqrt{w}} \Rightarrow C \cdot ( e^{x \cdot \sqrt{w}} - e^{-x \cdot \sqrt{w}})$
#
# Fourth, apply the boundary condition $u(\pi,t)=0$.<br>
# $X(\pi) = C \cdot ( e^{\pi \cdot \sqrt{w}} - e^{-\pi \cdot \sqrt{w}} )\, \qquad  C \neq 0$
#
# Fifth, simplify the resulting condition to obtain the eigenvalue equation <br>
# $e^{\pi \cdot \sqrt{w}} - e^{-\pi \cdot \sqrt{w}} = 0 \Rightarrow e^{\pi \cdot \sqrt{w}} = e^{-\pi \cdot \sqrt{w}} \Rightarrow e^{2 \cdot \pi \cdot \sqrt{w}} = 1$
#
# Since $e^{z} = 1$, it follows that $z=2\cdot \pi \cdot i \cdot k$ with $k \in \mathbb{Z} \setminus \{0\}$.
#
# Sixth, determine the eigenvalues $\lambda = \pm \sqrt{w} = \pm ik$ with $a=0$ and $b=k$<br>
# $2\cdot \pi \cdot \sqrt{w} = i \cdot 2 \cdot \pi \cdot k \Rightarrow \sqrt{w} = i \cdot k \Rightarrow w = -k^{2}$
#
# Seventh, insert the eigenvalues into the eigenfunction. <br>
# $X(x) = e^{a\cdot x}  \cdot (C_1 \cdot \cos(bx) + C_2 \cdot \sin(bx)) \Rightarrow X(x) = C_1 \cdot \cos(k\cdot x) + C_2 \cdot \sin(k\cdot x)$
#
# Eighth, apply the boundary condition $u(0,t) = 0$ to the eigenfunction.<br>
# $X(0) = C_1 \cdot \cos(0) + C_2 \cdot \sin(0) = C_1 \cdot 1 + C_2 \cdot 0 = C_1 = 0 \Rightarrow X(x) = C_2 \cdot \sin(k\cdot x)$
#
# Ninth, apply the boundary condition $u(\pi,t) = 0$ to the eigenfunction.<br>
# $X(\pi) = C_2 \cdot \sin(k \cdot \pi) = 0, \qquad C_2 \neq 0, \qquad k \in \mathbb{Z} \setminus \{0\}$
#
# Tenth, form the solution.<br>
# $u(x,t) = C_2\cdot sin(k \cdot x) \cdot C_3 \cdot e^{-a^2 \cdot k^2 \cdot t}, \qquad C_k := C_2C_3= \text{Konst.} $
#
# Eleventh, write the simplified form.<br>
# $u(x,t) = C_k \cdot sin(k \cdot x) \cdot e^{-a^2 \cdot k^2 \cdot t}$

# %% [markdown]
# ### 3.3 Fourier coefficient

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ### Task 4:  <font color=red>(2 points)</font>
#
# To calculate estimate results for the heatequation, $b_k$ must be estimated constant. Otherwhise there would be the need to calculate $b_k$ for every spot in the material.
#
# The last calculation that need to be done, is to calculate the Fourier-Coefitient $b_k$.
#
# Pleas use the equation to calculate the Fourier coefficient for the cosinus part $b_k$:
# $$
# b_k = \frac{2}{L} \int_{0}^{L} f(x)\,\sin\left(\frac{n\pi x}{L}\right)\,dx.
# $$
# $$b_k = \frac{2}{T}\int_{-\frac{T}{2}}^{\frac{T}{2}} f(t) \cdot \sin(k\cdot w \cdot t)\,dt, \qquad k = 1,2,\ldots$$
# $$
# f(x) = U(x,t) = 1
# $$
#
# <br>
# In case u need some help, this <a href="https://youtu.be/JC6tPsC3zts?t=476&si=1I-emzjRhfb46zTk" rel="noopener noreferrer"> video </a> showes how to calculate a Fourier-Coefitient.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Solution of Task 4</b>
#
#
#
# </div>

# %% [markdown]
# First insert the inital condition and the boundary condition in to the equation for the fourier-coeffitient<br>
# $b_k = \frac{2}{\pi} \int_{0}^{\pi} 1 \cdot \sin(k \cdot x)\,\mathrm{d}x$
#
# Second integrate the equation for the boundaries and and solve the equation <br>
# $b_k = \frac{2\cdot \,(1-\cos(k \cdot \pi))}{\pi \cdot k} \Rightarrow \cos(k \cdot \pi) = (-1)^k \Rightarrow b_k = \frac{2\cdot \,(1-(-1)^k)}{\pi \cdot k}$
#
# Third find the solutions for straight and odd values for the fourier coeffizient<br>
# $b_k = \frac{2\cdot \,(1-(-1)^2)}{\pi\cdot 2} = \frac{2\cdot \,(1-1)}{2 \cdot \pi}= 0 \Rightarrow  b_k = 0$
# This means for straight $k$ the $b_k$ is always zero <br>
# $b_k = \frac{2\cdot \,(1-(-1)^3)}{\pi\cdot 3} = \frac{2\cdot \,(1+1)}{3 \cdot \pi} = \frac{4}{3 \cdot \pi} \Rightarrow b_k = \frac{4}{\pi \cdot k}$
# This means for odd $k$ the $b_k$ is $\frac{4}{\pi \cdot k}$
#
# Fourth formulat the solution for the heatequation through inserting the fourier-coeffitient in the product-equation<br>
# $u(x,t) = \sum_{k=1}^{\infty} \frac{4}{\pi \cdot k}\cdot \,\sin(k \cdot x)\cdot \,e^{-a^2 \cdot k^2 \cdot t}$

# %% [markdown]
# ## 4 Implementation & Visualization

# %% [markdown]
# ### 4.1 Simple sine
# A single sine already satisfies $u(0,t)=u(\pi,t)=0$ for all $t$.
# It is not the correct initial condition for $u(x,0)=1$ but for now we will ignore this initial condition.

# %%
# Parameters of simple sine:
a2 = 1.0    # thermal diffusivity squared
k2 = 1.0    # wave number squared (k=1 for single sine)
L = np.pi   # Length of rod
nx = 300    # Number of measure points on x-axis
x_vals = np.linspace(0.0, L, nx)    # actual positions of the measure points from 0 to L

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ### Task 5:  <font color=red>(2 points)</font>
#
# Implement/Define the function `u_sin_xt()` with the solution from task 3 and leave the parameter $b_k$ out for now. The function should return the solution from task 3.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Solution of Task 5</b>
#
#
#
# </div>

# %%
# Simple One sine (k=1): u(x,t) = sin(x) * exp(-a^2*k^2*t)
def u_sin_xt(x, t, a2, k2):
    # Single sine with homogeneous Dirichlet Boundary conditions
    return np.sin(x) * np.exp(-a2 * k2* t)  # Initial graph meets exponential decay time factor

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Solution of Task 5</b>
#
# Execute the code below to test your function
#
#
# </div>

# %%
plt.figure(figsize=(7.5, 4))    # Set figure size figsize=(width, height)
for t in (0.0, 0.1, 0.5, 1.0):  # Loop for the defined time steps
    # Compute sine-mode temperature at the x_vals for the current time t and plot it. The line label shows the time and legend() looks for labels
    plt.plot(x_vals, u_sin_xt(x_vals, t, a2, k2), label=f"t={t:g}")   
plt.xlabel("x")    # Label x-axis with "x"
plt.ylabel("u(x,t)")    # Label y-axis with "u(x,t)"
plt.title("Single sine")    # Title of the plot
plt.legend()    # Shows labels, if set
plt.show()      # Display the calculated plot

# %% [markdown]
# ### 4.2 Fourier sine
#
# We already solved the PDE with Fourier in Task 4 and now it is time to simulate it.

# %%
# Parameters of Fourier sinus modes:
a2 = 1.0        # thermal diffusivity a^2
N = 50          # number of Fourier terms
L = np.pi       # rod length (x in [0, pi])

nx = 300        # Number of measure points on x-axis
x_vals = np.linspace(0.0, L, nx)     # actual positions of the measure points from 0 to L # actual positions of the measure points from 0 to L

# Times for line plots and checks
plot_times = [0.0, 0.01, 0.1, 1.0]

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ### Task 6:  <font color=red>(5 points)</font>
#
# Implement/Define the functions `coeffs()` and `u_xt()` with the solution from Task 4 for $b_k$. `coeffs()` has the target to calculate the Fourier sinus coefficient $b_k$, `u_xt()` has the target to calculate the temperature $u(x,t)$ at time $t$ and location $x$ based on the fourier series.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Solution of Task 6</b>
#
#
#
# </div>

# %%
# Calculates the fourier sinus coefficient b_k for f(x)=1
def coeff(N):
    k = np.arange(1, N + 1, dtype=float)    # Create an array k with numbers from 1 to N (k=1 big waves, k=100 small waves)
    b_k = 2.0 * (1.0 - np.cos(k * np.pi)) / (np.pi * k)    # Calculate fourier coefficient b_k with given formula
    return k, b_k

# Calculates the temperature u(x,t) at time t and location x based on the fourier series 
def u_xt(x, t, a2, N):
    x_arr = np.asarray(x, dtype=float)  # Convert input x to array
    x_flat = x_arr.reshape(1, -1)   # Make an array with 1 row and as many columns as x_arr has elements
    k, b_k = coeff(N)  # Get fourier coefficients
    k = k[:, None]  # Change array k to one column and as many rows as k has elements
    terms = b_k[:, None] * np.sin(k * x_flat) * np.exp(-a2 * (k ** 2) * t)  # Calculate the terms of the Fourier series for each k and x at the time t
    u_flat = terms.sum(axis=0)  # Add all the fourier terms together for each x to get the temperature u(x,t) at time t
    return u_flat.reshape(x_arr.shape)  # Reshape the flat array back to the original shape of x_arr (reshape important, when function is called with plt.plot)

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Solution of Task 6</b>
#
# Execute the code below to test your function
#
#
# </div>

# %%
# Checks if the numeric implementation satisfies boundary conditions and initial value approximation
for t in (0.01, 0.1, 1.0):
    left = u_xt(0.0, t, a2, N)
    right = u_xt(L, t, a2, N)
    print(f"t={t:.2f}: u(0,t)={left}, u(pi,t)={right}") # sin(k*pi) for example is not exactly zero, but extremely close to zero, which is acceptable for practical purposes

# Convergence check at t=0 for different N
plt.figure(figsize=(7.5, 4))
for N_test in (1, 10, 50, 200):
    plt.plot(x_vals, u_xt(x_vals, 0.0, a2, N_test), label=f"N={N_test}")
plt.plot(x_vals, np.ones_like(x_vals), "k--", label="u(x,0)=1")
plt.xlabel("x")
plt.ylabel("u(x,0)")
plt.title("Initial condition approximation")
plt.legend()
plt.show()

# Plot u(x,t) for every array value in plot_times
plt.figure(figsize=(7.5, 4))
for t in plot_times:
    plt.plot(x_vals, u_xt(x_vals, t, a2, N), label=f"t={t:g}")
plt.xlabel("x")
plt.ylabel("u(x,t)")
plt.title("Fourier sine solution at several times steps")
plt.legend()
plt.show()

# %% [markdown]
# ## Literature
#  - [J.Koch, M.Stämpfle: Mathematik für das Ingenieurstudium](https://www.hanser-fachbuch.de/buch/Mathematik+fuer+das+Ingenieurstudium/9783446451667)
#  - [NumPy Documentation](https://numpy.org/doc/stable/index.html)
